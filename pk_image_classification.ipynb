# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenkumaresan/model-learning/blob/main/pk_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Custom CNN

# %%
import os
import shutil

# Path to the cache directory used by kagglehub
cache_directory = "/root/.cache/kagglehub"

# Check if the cache directory exists and delete it
if os.path.exists(cache_directory):
    shutil.rmtree(cache_directory)
    print("Cache cleared successfully.")
else:
    print("Cache directory not found.")
# Out:
# Cache directory not found.

# %%
import os
import kagglehub

# Download the dataset using kagglehub
path = kagglehub.dataset_download("kausthubkannan/5-flower-types-classification-dataset")
print("Path to dataset files:", path)

# Function to print the directory structure
def print_directory_structure(directory):
    for root, dirs, files in os.walk(directory):
        level = root.replace(directory, '').count(os.sep)
        indent = ' ' * 4 * level
        print(f"{indent}{os.path.basename(root)}/")
        sub_indent = ' ' * 4 * (level + 1)
        # for file in files:
        #     print(f"{sub_indent}{file}")

# Print the directory structure of the entire dataset
print("\nDirectory structure of the dataset:")
print_directory_structure(path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kausthubkannan/5-flower-types-classification-dataset?dataset_version_number=1...
# 100%|██████████| 242M/242M [00:12<00:00, 20.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1
#
# Directory structure of the dataset:
# 1/
#     flower_images/
#         Tulip/
#         Lilly/
#         Lotus/
#         Orchid/
#         Sunflower/

# %% [markdown]
# #### Split the dataset into test, training and validation

# %%
import os
import shutil
import random
import kagglehub

# Download the dataset using kagglehub
path = kagglehub.dataset_download("kausthubkannan/5-flower-types-classification-dataset")
print("Path to dataset files:", path)

# Set the path to the flower_images directory
flower_images_dir = os.path.join(path, "flower_images")
base_dir = path

# Automatically create paths for train, validation, and test directories
train_directory = os.path.join(base_dir, "train")
validation_directory = os.path.join(base_dir, "validation")
test_directory = os.path.join(base_dir, "test")

# Create directories for training, validation, and test sets
os.makedirs(train_directory, exist_ok=True)
os.makedirs(validation_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

# Iterate over each class folder in flower_images
for class_name in os.listdir(flower_images_dir):
    class_dir = os.path.join(flower_images_dir, class_name)

    if os.path.isdir(class_dir):
        # Get a list of all image files in this class
        images = [file for file in os.listdir(class_dir) if file.lower().endswith(('.jpg', '.jpeg', '.png'))]
        random.shuffle(images)  # Shuffle the images randomly

        # Calculate the number of images for each split
        total_images = len(images)
        train_count = int(total_images * 0.7)
        validation_count = int(total_images * 0.2)

        # Create class directories in train, validation, and test folders
        os.makedirs(os.path.join(train_directory, class_name), exist_ok=True)
        os.makedirs(os.path.join(validation_directory, class_name), exist_ok=True)
        os.makedirs(os.path.join(test_directory, class_name), exist_ok=True)

        # Split and copy images to the respective directories
        for i, image in enumerate(images):
            src_path = os.path.join(class_dir, image)
            if i < train_count:
                dest_path = os.path.join(train_directory, class_name, image)
            elif i < train_count + validation_count:
                dest_path = os.path.join(validation_directory, class_name, image)
            else:
                dest_path = os.path.join(test_directory, class_name, image)

            shutil.copy(src_path, dest_path)

# Function to count the number of images in a directory
def count_images_in_directory(directory):
    count = 0
    for root, _, files in os.walk(directory):
        count += len([file for file in files if file.lower().endswith(('.jpg', '.jpeg', '.png'))])
    return count

# Print the number of images in each directory
print("\nNumber of images in each directory:")
print("Train Directory:", count_images_in_directory(train_directory))
print("Validation Directory:", count_images_in_directory(validation_directory))
print("Test Directory:", count_images_in_directory(test_directory))
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1
#
# Number of images in each directory:
# Train Directory: 3499
# Validation Directory: 999
# Test Directory: 501

# %% [markdown]
# #### Install necessary

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# #### Load and Preprocess the Data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_directory = train_directory
print('train ', train_directory)
validation_directory = validation_directory
print('validation ', validation_directory)

# Create data generators for loading and augmenting images
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values between 0 and 1
    rotation_range=30,  # Data augmentation: rotate images
    width_shift_range=0.2,  # Data augmentation: shift images horizontally
    height_shift_range=0.2,  # Data augmentation: shift images vertically
    shear_range=0.2,  # Shear transformation
    zoom_range=0.2,  # Zoom in/out
    horizontal_flip=True,  # Flip images horizontally
    fill_mode='nearest'  # Fill strategy for augmented images
)

validation_datagen = ImageDataGenerator(rescale=1.0/255)

# Load images from directories
train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=(150, 150),  # Resize images to a fixed size
    batch_size=32,
    class_mode='categorical'  # Use 'binary' if you have only two classes
)

validation_generator = validation_datagen.flow_from_directory(
    validation_directory,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# train  /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1/train
# validation  /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1/validation
# Found 3499 images belonging to 5 classes.
# Found 999 images belonging to 5 classes.

# %% [markdown]
# ###  v2.0 Define the CNN Model Architecture

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the CNN model
def build_custom_cnn(input_shape=(150, 150, 3), num_classes=5):
    model = models.Sequential([
        # Convolutional Layer 1
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.MaxPooling2D((2, 2)),

        # Convolutional Layer 2
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),

        # Convolutional Layer 3
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),

        # Fully Connected Layers
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),  # Regularization
        layers.Dense(num_classes, activation='softmax')  # Output layer
    ])

    return model

# %% [markdown]
# ### Compile the Model

# %%
from tensorflow.keras import models, layers, Input
from tensorflow.keras.metrics import Precision, Recall

# Define the model
model = models.Sequential()

# Add Input layer and Conv2D layers
model.add(Input(shape=(150, 150, 3)))  # Use Input layer explicitly
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Add Flatten and Dense layers
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(5, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(name='precision'), Recall(name='recall')])

# Print model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 148, 148, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 36992)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │      18,940,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │           2,565 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,036,357 (72.62 MB)
#  Trainable params: 19,036,293 (72.62 MB)
#  Non-trainable params: 64 (256.00 B)

# %% [markdown]
# ###  Preprocess the Data
# Use ImageDataGenerator for data preprocessing and augmentation. This ensures the model gets more diverse training examples.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set up data generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255,          # Normalize pixel values to [0, 1]
    rotation_range=30,        # Random rotations
    width_shift_range=0.2,    # Horizontal shifts
    height_shift_range=0.2,   # Vertical shifts
    shear_range=0.2,          # Shearing transformations
    zoom_range=0.2,           # Zoom-in and zoom-out
    horizontal_flip=True,     # Random horizontal flips
    fill_mode='nearest'       # Fill missing pixels
)

validation_datagen = ImageDataGenerator(rescale=1.0/255)

# Create generators
train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=(150, 150),   # Image size
    batch_size=32,
    class_mode='categorical'  # Multiclass classification
)

validation_generator = validation_datagen.flow_from_directory(
    validation_directory,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 3499 images belonging to 5 classes.
# Found 999 images belonging to 5 classes.

# %% [markdown]
# ### Train the Model Train the CNN on the dataset:

# %%
## Train the model with 50 epochs

# Train the model
history = model.fit(
    train_generator,
    epochs=50,  # Adjust based on performance
    validation_data=validation_generator
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 35s 273ms/step - accuracy: 0.3906 - loss: 2.6554 - precision: 0.5412 - recall: 0.1737 - val_accuracy: 0.2663 - val_loss: 1.5616 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.5133 - loss: 1.2118 - precision: 0.6932 - recall: 0.2444 - val_accuracy: 0.3013 - val_loss: 1.5936 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.5438 - loss: 1.1356 - precision: 0.7374 - recall: 0.3060 - val_accuracy: 0.4905 - val_loss: 1.2745 - val_precision: 0.8252 - val_recall: 0.1181
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.5774 - loss: 1.0509 - precision: 0.7433 - recall: 0.3624 - val_accuracy: 0.5676 - val_loss: 1.1772 - val_precision: 0.9133 - val_recall: 0.1582
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.5659 - loss: 1.0766 - precision: 0.7944 - recall: 0.3325 - val_accuracy: 0.6286 - val_loss: 1.0001 - val_precision: 0.8801 - val_recall: 0.3453
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.6007 - loss: 0.9878 - precision: 0.7900 - recall: 0.4059 - val_accuracy: 0.6156 - val_loss: 1.0109 - val_precision: 0.8242 - val_recall: 0.3754
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.6190 - loss: 0.9762 - precision: 0.7605 - recall: 0.4093 - val_accuracy: 0.6306 - val_loss: 0.9664 - val_precision: 0.8049 - val_recall: 0.4585
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.6430 - loss: 0.9423 - precision: 0.7821 - recall: 0.4435 - val_accuracy: 0.6517 - val_loss: 0.9397 - val_precision: 0.8145 - val_recall: 0.4835
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.6410 - loss: 0.9110 - precision: 0.7855 - recall: 0.4761 - val_accuracy: 0.6276 - val_loss: 0.9774 - val_precision: 0.7564 - val_recall: 0.4444
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.6046 - loss: 0.9577 - precision: 0.7784 - recall: 0.4207 - val_accuracy: 0.6687 - val_loss: 0.9079 - val_precision: 0.7736 - val_recall: 0.5165
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 232ms/step - accuracy: 0.6547 - loss: 0.8754 - precision: 0.7739 - recall: 0.5111 - val_accuracy: 0.6767 - val_loss: 0.8511 - val_precision: 0.8082 - val_recall: 0.5315
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.6693 - loss: 0.8368 - precision: 0.7937 - recall: 0.5240 - val_accuracy: 0.4004 - val_loss: 2.3976 - val_precision: 0.4093 - val_recall: 0.3884
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.6761 - loss: 0.8352 - precision: 0.7930 - recall: 0.5280 - val_accuracy: 0.6897 - val_loss: 0.8922 - val_precision: 0.7779 - val_recall: 0.5716
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.6565 - loss: 0.8659 - precision: 0.7817 - recall: 0.5140 - val_accuracy: 0.6977 - val_loss: 0.8047 - val_precision: 0.8042 - val_recall: 0.5756
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.6863 - loss: 0.7960 - precision: 0.8064 - recall: 0.5558 - val_accuracy: 0.7047 - val_loss: 0.7783 - val_precision: 0.8091 - val_recall: 0.6026
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 232ms/step - accuracy: 0.6764 - loss: 0.8384 - precision: 0.7932 - recall: 0.5275 - val_accuracy: 0.6627 - val_loss: 0.8910 - val_precision: 0.7889 - val_recall: 0.5385
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.6851 - loss: 0.7994 - precision: 0.8179 - recall: 0.5485 - val_accuracy: 0.6867 - val_loss: 0.8598 - val_precision: 0.7706 - val_recall: 0.5886
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.7007 - loss: 0.8081 - precision: 0.8108 - recall: 0.5711 - val_accuracy: 0.6927 - val_loss: 0.8119 - val_precision: 0.8050 - val_recall: 0.5746
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.7036 - loss: 0.7612 - precision: 0.8055 - recall: 0.5796 - val_accuracy: 0.7067 - val_loss: 0.8356 - val_precision: 0.7953 - val_recall: 0.5756
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.7011 - loss: 0.7592 - precision: 0.7969 - recall: 0.5923 - val_accuracy: 0.6937 - val_loss: 0.7893 - val_precision: 0.8109 - val_recall: 0.5495
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.7170 - loss: 0.7484 - precision: 0.8074 - recall: 0.6018 - val_accuracy: 0.7037 - val_loss: 0.7700 - val_precision: 0.8108 - val_recall: 0.5836
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.6908 - loss: 0.7721 - precision: 0.7993 - recall: 0.5860 - val_accuracy: 0.6376 - val_loss: 0.8965 - val_precision: 0.7195 - val_recall: 0.5676
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.7223 - loss: 0.7286 - precision: 0.8111 - recall: 0.6054 - val_accuracy: 0.7137 - val_loss: 0.8054 - val_precision: 0.8083 - val_recall: 0.6036
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.7203 - loss: 0.7244 - precision: 0.8148 - recall: 0.6203 - val_accuracy: 0.6867 - val_loss: 0.8751 - val_precision: 0.7284 - val_recall: 0.6416
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.7398 - loss: 0.7183 - precision: 0.8236 - recall: 0.6199 - val_accuracy: 0.7518 - val_loss: 0.7079 - val_precision: 0.8276 - val_recall: 0.6486
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.7292 - loss: 0.6922 - precision: 0.8208 - recall: 0.6306 - val_accuracy: 0.7467 - val_loss: 0.7173 - val_precision: 0.8126 - val_recall: 0.6817
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.7230 - loss: 0.7176 - precision: 0.8018 - recall: 0.6266 - val_accuracy: 0.7137 - val_loss: 0.7317 - val_precision: 0.7855 - val_recall: 0.6306
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.7281 - loss: 0.6994 - precision: 0.8224 - recall: 0.6292 - val_accuracy: 0.7417 - val_loss: 0.7170 - val_precision: 0.8359 - val_recall: 0.6476
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.7400 - loss: 0.7043 - precision: 0.8118 - recall: 0.6392 - val_accuracy: 0.6757 - val_loss: 0.8563 - val_precision: 0.7678 - val_recall: 0.5826
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 231ms/step - accuracy: 0.7237 - loss: 0.6913 - precision: 0.8189 - recall: 0.6284 - val_accuracy: 0.7277 - val_loss: 0.7380 - val_precision: 0.8263 - val_recall: 0.6426
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.7526 - loss: 0.6444 - precision: 0.8294 - recall: 0.6663 - val_accuracy: 0.7247 - val_loss: 0.7494 - val_precision: 0.8067 - val_recall: 0.6476
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.7405 - loss: 0.6826 - precision: 0.8177 - recall: 0.6378 - val_accuracy: 0.7528 - val_loss: 0.6843 - val_precision: 0.8278 - val_recall: 0.6737
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.7308 - loss: 0.7033 - precision: 0.8116 - recall: 0.6403 - val_accuracy: 0.7247 - val_loss: 0.7318 - val_precision: 0.8061 - val_recall: 0.6577
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.7612 - loss: 0.6394 - precision: 0.8351 - recall: 0.6753 - val_accuracy: 0.7447 - val_loss: 0.7232 - val_precision: 0.8290 - val_recall: 0.6356
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.7560 - loss: 0.6464 - precision: 0.8288 - recall: 0.6759 - val_accuracy: 0.7457 - val_loss: 0.6842 - val_precision: 0.8122 - val_recall: 0.6927
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.7594 - loss: 0.6377 - precision: 0.8237 - recall: 0.6766 - val_accuracy: 0.7307 - val_loss: 0.7429 - val_precision: 0.8120 - val_recall: 0.6356
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.7571 - loss: 0.6258 - precision: 0.8210 - recall: 0.6738 - val_accuracy: 0.7287 - val_loss: 0.7205 - val_precision: 0.8076 - val_recall: 0.6386
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.7415 - loss: 0.6575 - precision: 0.8236 - recall: 0.6588 - val_accuracy: 0.7487 - val_loss: 0.7079 - val_precision: 0.8424 - val_recall: 0.6637
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.7585 - loss: 0.6407 - precision: 0.8298 - recall: 0.6808 - val_accuracy: 0.7528 - val_loss: 0.6834 - val_precision: 0.8206 - val_recall: 0.6777
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.7498 - loss: 0.6620 - precision: 0.8193 - recall: 0.6709 - val_accuracy: 0.7277 - val_loss: 0.7596 - val_precision: 0.7978 - val_recall: 0.6517
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.7751 - loss: 0.6130 - precision: 0.8402 - recall: 0.6945 - val_accuracy: 0.7307 - val_loss: 0.7938 - val_precision: 0.7878 - val_recall: 0.6727
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.7686 - loss: 0.6020 - precision: 0.8236 - recall: 0.6942 - val_accuracy: 0.7437 - val_loss: 0.7105 - val_precision: 0.8040 - val_recall: 0.6857
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.7905 - loss: 0.5579 - precision: 0.8523 - recall: 0.7255 - val_accuracy: 0.7417 - val_loss: 0.6898 - val_precision: 0.8078 - val_recall: 0.6647
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.7725 - loss: 0.6097 - precision: 0.8367 - recall: 0.7019 - val_accuracy: 0.7427 - val_loss: 0.7836 - val_precision: 0.7973 - val_recall: 0.6967
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.7657 - loss: 0.6400 - precision: 0.8265 - recall: 0.6961 - val_accuracy: 0.7878 - val_loss: 0.6110 - val_precision: 0.8454 - val_recall: 0.7227
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.7980 - loss: 0.5454 - precision: 0.8437 - recall: 0.7422 - val_accuracy: 0.7608 - val_loss: 0.7307 - val_precision: 0.8055 - val_recall: 0.7297
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.7912 - loss: 0.5613 - precision: 0.8343 - recall: 0.7273 - val_accuracy: 0.7588 - val_loss: 0.6329 - val_precision: 0.8223 - val_recall: 0.7087
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.7764 - loss: 0.5842 - precision: 0.8450 - recall: 0.7148 - val_accuracy: 0.7037 - val_loss: 0.8627 - val_precision: 0.7617 - val_recall: 0.6657
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.7825 - loss: 0.5873 - precision: 0.8359 - recall: 0.7081 - val_accuracy: 0.7548 - val_loss: 0.7541 - val_precision: 0.8274 - val_recall: 0.6767
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 234ms/step - accuracy: 0.7506 - loss: 0.6533 - precision: 0.8117 - recall: 0.6801 - val_accuracy: 0.7678 - val_loss: 0.6654 - val_precision: 0.8212 - val_recall: 0.7217
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.7912 - loss: 0.5724 - precision: 0.8448 - recall: 0.7375 - val_accuracy: 0.7768 - val_loss: 0.6463 - val_precision: 0.8224 - val_recall: 0.7277
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.7899 - loss: 0.5509 - precision: 0.8419 - recall: 0.7275 - val_accuracy: 0.7718 - val_loss: 0.6221 - val_precision: 0.8187 - val_recall: 0.7277
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.7982 - loss: 0.5237 - precision: 0.8505 - recall: 0.7440 - val_accuracy: 0.7918 - val_loss: 0.6081 - val_precision: 0.8442 - val_recall: 0.7538
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.7987 - loss: 0.5332 - precision: 0.8455 - recall: 0.7362 - val_accuracy: 0.7968 - val_loss: 0.6146 - val_precision: 0.8538 - val_recall: 0.7307
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.8058 - loss: 0.5224 - precision: 0.8468 - recall: 0.7567 - val_accuracy: 0.7968 - val_loss: 0.6458 - val_precision: 0.8563 - val_recall: 0.7277
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.8030 - loss: 0.5431 - precision: 0.8517 - recall: 0.7399 - val_accuracy: 0.7828 - val_loss: 0.6072 - val_precision: 0.8366 - val_recall: 0.7327
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8155 - loss: 0.5106 - precision: 0.8566 - recall: 0.7580 - val_accuracy: 0.8038 - val_loss: 0.5691 - val_precision: 0.8542 - val_recall: 0.7568
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.8054 - loss: 0.5369 - precision: 0.8494 - recall: 0.7395 - val_accuracy: 0.7968 - val_loss: 0.5963 - val_precision: 0.8376 - val_recall: 0.7487
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.7972 - loss: 0.5482 - precision: 0.8481 - recall: 0.7426 - val_accuracy: 0.8048 - val_loss: 0.5791 - val_precision: 0.8419 - val_recall: 0.7568
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.8002 - loss: 0.5429 - precision: 0.8434 - recall: 0.7484 - val_accuracy: 0.7878 - val_loss: 0.6011 - val_precision: 0.8296 - val_recall: 0.7457
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 234ms/step - accuracy: 0.8034 - loss: 0.5159 - precision: 0.8472 - recall: 0.7488 - val_accuracy: 0.7908 - val_loss: 0.6292 - val_precision: 0.8312 - val_recall: 0.7638
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.7930 - loss: 0.5385 - precision: 0.8436 - recall: 0.7436 - val_accuracy: 0.7808 - val_loss: 0.6634 - val_precision: 0.8426 - val_recall: 0.7287
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.8038 - loss: 0.5400 - precision: 0.8529 - recall: 0.7564 - val_accuracy: 0.7938 - val_loss: 0.6365 - val_precision: 0.8440 - val_recall: 0.7417
# Epoch 64/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8090 - loss: 0.5457 - precision: 0.8528 - recall: 0.7512 - val_accuracy: 0.7728 - val_loss: 0.6890 - val_precision: 0.8151 - val_recall: 0.7147
# Epoch 65/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.8038 - loss: 0.5638 - precision: 0.8464 - recall: 0.7404 - val_accuracy: 0.8028 - val_loss: 0.6310 - val_precision: 0.8413 - val_recall: 0.7538
# Epoch 66/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8122 - loss: 0.5046 - precision: 0.8581 - recall: 0.7589 - val_accuracy: 0.7738 - val_loss: 0.8938 - val_precision: 0.8132 - val_recall: 0.7277
# Epoch 67/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.8220 - loss: 0.4855 - precision: 0.8655 - recall: 0.7697 - val_accuracy: 0.7788 - val_loss: 0.6803 - val_precision: 0.8228 - val_recall: 0.7437
# Epoch 68/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 232ms/step - accuracy: 0.8150 - loss: 0.5180 - precision: 0.8561 - recall: 0.7599 - val_accuracy: 0.8038 - val_loss: 0.6037 - val_precision: 0.8319 - val_recall: 0.7778
# Epoch 69/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.8115 - loss: 0.5109 - precision: 0.8607 - recall: 0.7670 - val_accuracy: 0.7828 - val_loss: 0.6395 - val_precision: 0.8259 - val_recall: 0.7457
# Epoch 70/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.8236 - loss: 0.4744 - precision: 0.8606 - recall: 0.7703 - val_accuracy: 0.8068 - val_loss: 0.6122 - val_precision: 0.8427 - val_recall: 0.7668
# Epoch 71/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.8234 - loss: 0.4944 - precision: 0.8629 - recall: 0.7666 - val_accuracy: 0.8088 - val_loss: 0.5529 - val_precision: 0.8426 - val_recall: 0.7718
# Epoch 72/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.8241 - loss: 0.4804 - precision: 0.8691 - recall: 0.7755 - val_accuracy: 0.7948 - val_loss: 0.6596 - val_precision: 0.8359 - val_recall: 0.7698
# Epoch 73/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.8407 - loss: 0.4591 - precision: 0.8797 - recall: 0.7932 - val_accuracy: 0.7918 - val_loss: 0.5692 - val_precision: 0.8516 - val_recall: 0.7407
# Epoch 74/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.8099 - loss: 0.5126 - precision: 0.8568 - recall: 0.7570 - val_accuracy: 0.8018 - val_loss: 0.5647 - val_precision: 0.8498 - val_recall: 0.7588
# Epoch 75/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8326 - loss: 0.4618 - precision: 0.8727 - recall: 0.7886 - val_accuracy: 0.8018 - val_loss: 0.5828 - val_precision: 0.8419 - val_recall: 0.7518
# Epoch 76/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8226 - loss: 0.4747 - precision: 0.8753 - recall: 0.7785 - val_accuracy: 0.8208 - val_loss: 0.6051 - val_precision: 0.8505 - val_recall: 0.7858
# Epoch 77/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 241ms/step - accuracy: 0.8367 - loss: 0.4327 - precision: 0.8708 - recall: 0.7999 - val_accuracy: 0.7888 - val_loss: 0.6908 - val_precision: 0.8305 - val_recall: 0.7698
# Epoch 78/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.8141 - loss: 0.4946 - precision: 0.8559 - recall: 0.7711 - val_accuracy: 0.7808 - val_loss: 0.7052 - val_precision: 0.8097 - val_recall: 0.7497
# Epoch 79/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 234ms/step - accuracy: 0.8151 - loss: 0.5182 - precision: 0.8571 - recall: 0.7659 - val_accuracy: 0.8108 - val_loss: 0.6450 - val_precision: 0.8418 - val_recall: 0.7828
# Epoch 80/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.8214 - loss: 0.4891 - precision: 0.8585 - recall: 0.7788 - val_accuracy: 0.8218 - val_loss: 0.5782 - val_precision: 0.8575 - val_recall: 0.7948
# Epoch 81/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8184 - loss: 0.4675 - precision: 0.8613 - recall: 0.7829 - val_accuracy: 0.8148 - val_loss: 0.6261 - val_precision: 0.8462 - val_recall: 0.7878
# Epoch 82/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.8281 - loss: 0.4587 - precision: 0.8628 - recall: 0.7891 - val_accuracy: 0.8088 - val_loss: 0.6829 - val_precision: 0.8357 - val_recall: 0.7788
# Epoch 83/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 233ms/step - accuracy: 0.8191 - loss: 0.4953 - precision: 0.8581 - recall: 0.7746 - val_accuracy: 0.7998 - val_loss: 0.6093 - val_precision: 0.8407 - val_recall: 0.7658
# Epoch 84/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.8338 - loss: 0.4513 - precision: 0.8677 - recall: 0.7906 - val_accuracy: 0.8108 - val_loss: 0.6246 - val_precision: 0.8594 - val_recall: 0.7708
# Epoch 85/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 236ms/step - accuracy: 0.8211 - loss: 0.4930 - precision: 0.8618 - recall: 0.7742 - val_accuracy: 0.8048 - val_loss: 0.8378 - val_precision: 0.8243 - val_recall: 0.7798
# Epoch 86/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.8371 - loss: 0.4608 - precision: 0.8680 - recall: 0.7973 - val_accuracy: 0.8008 - val_loss: 0.6775 - val_precision: 0.8258 - val_recall: 0.7688
# Epoch 87/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.8340 - loss: 0.4407 - precision: 0.8759 - recall: 0.7974 - val_accuracy: 0.7648 - val_loss: 0.8047 - val_precision: 0.7871 - val_recall: 0.7437
# Epoch 88/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.8207 - loss: 0.5114 - precision: 0.8577 - recall: 0.7759 - val_accuracy: 0.8128 - val_loss: 0.6687 - val_precision: 0.8340 - val_recall: 0.7848
# Epoch 89/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.8266 - loss: 0.4442 - precision: 0.8687 - recall: 0.7879 - val_accuracy: 0.8058 - val_loss: 0.6100 - val_precision: 0.8288 - val_recall: 0.7708
# Epoch 90/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 27s 233ms/step - accuracy: 0.8564 - loss: 0.4206 - precision: 0.8914 - recall: 0.8150 - val_accuracy: 0.8238 - val_loss: 0.6033 - val_precision: 0.8614 - val_recall: 0.8088
# Epoch 91/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.8474 - loss: 0.4274 - precision: 0.8840 - recall: 0.8034 - val_accuracy: 0.7758 - val_loss: 0.7023 - val_precision: 0.8028 - val_recall: 0.7457
# Epoch 92/100

# %% [markdown]
# ### Evaluate on the Test Set,  after training, evaluate the model on the test set:

# %%
# Load the test data
test_datagen = ImageDataGenerator(rescale=1.0/255)
test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)

# Evaluate the model
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)

# Print the results
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Precision: {test_precision * 100:.2f}%")
print(f"Test Recall: {test_recall * 100:.2f}%")
# Out:
# Found 501 images belonging to 5 classes.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.7661 - loss: 0.6011 - precision: 0.8113 - recall: 0.6986
# Test Loss: 0.6501
# Test Accuracy: 74.45%
# Test Precision: 78.94%
# Test Recall: 68.06%

# %% [markdown]
# ### Plot training and validation accuracy/loss:

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Evaluate the Model with Confusion Matrix

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Generate predictions
test_generator.reset()
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Confusion Matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# Classification Report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step
#               precision    recall  f1-score   support
#
#        Lilly       0.23      0.30      0.26       101
#        Lotus       0.17      0.16      0.17       100
#       Orchid       0.19      0.16      0.17       100
#    Sunflower       0.19      0.20      0.20       100
#        Tulip       0.23      0.21      0.22       100
#
#     accuracy                           0.21       501
#    macro avg       0.20      0.21      0.20       501
# weighted avg       0.20      0.21      0.20       501

# %% [markdown]
# Visualizing Model Predictions

# %%
# Visualize predictions
def visualize_predictions(generator, num_images=10):
    class_labels = list(generator.class_indices.keys())
    batch = next(generator)
    images, labels = batch[0], batch[1]

    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(labels, axis=1)

    plt.figure(figsize=(15, 10))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i])
        plt.title(f"True: {class_labels[true_classes[i]]}\nPred: {class_labels[predicted_classes[i]]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Visualize predictions on the test set
visualize_predictions(test_generator, num_images=10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step

# %% [markdown]
# ### Area under the curve

# %% [markdown]
# Get the Predicted Probabilities

# %%
y_pred_prob = model.predict(test_generator)  # Predicted probabilities for each class
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step

# %% [markdown]
# Binarize the True Labels

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
y_test_binarized = lb.fit_transform(test_generator.classes)  # True labels in binary format
class_names = test_generator.class_indices.keys()  # Class names

# %% [markdown]
# Calculate AUC and ROC for Each Class

# %%
from sklearn.metrics import roc_curve, auc

fpr = {}
tpr = {}
roc_auc = {}

for i, class_name in enumerate(class_names):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Print the AUC for each class
for i, class_name in enumerate(class_names):
    print(f"AUC for {class_name}: {roc_auc[i]:.2f}")
# Out:
# AUC for Lilly: 0.55
# AUC for Lotus: 0.55
# AUC for Orchid: 0.47
# AUC for Sunflower: 0.50
# AUC for Tulip: 0.44

# %% [markdown]
# Plot ROC Curves for All Classes

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
for i, class_name in enumerate(class_names):
    plt.plot(fpr[i], tpr[i], label=f'{class_name} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line (random classifier)
plt.title('ROC Curve for Multi-Class Classification')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Compute and Plot the Macro and Micro AUC

# %%
from sklearn.metrics import roc_auc_score

# Macro AUC (average of AUCs for all classes)
macro_auc = roc_auc_score(y_test_binarized, y_pred_prob, average="macro")
print(f"Macro AUC: {macro_auc:.2f}")

# Micro AUC (global performance across all classes)
micro_auc = roc_auc_score(y_test_binarized, y_pred_prob, average="micro")
print(f"Micro AUC: {micro_auc:.2f}")
# Out:
# Macro AUC: 0.50
# Micro AUC: 0.51

# %% [markdown]
# ### Looking to split into 2 ways - test and training

# %%
import os
import shutil
import random
import kagglehub

# Download the dataset using kagglehub
path = kagglehub.dataset_download("kausthubkannan/5-flower-types-classification-dataset")
print("Path to dataset files:", path)

# Set the path to the flower_images directory
flower_images_dir = os.path.join(path, "flower_images")
base_dir = path

# Automatically create paths for train and test directories
train_directory = os.path.join(base_dir, "train")
test_directory = os.path.join(base_dir, "test")

# Create directories for training and test sets
os.makedirs(train_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

# Iterate over each class folder in flower_images
for class_name in os.listdir(flower_images_dir):
    class_dir = os.path.join(flower_images_dir, class_name)

    if os.path.isdir(class_dir):
        # Get a list of all image files in this class
        images = [file for file in os.listdir(class_dir) if file.lower().endswith(('.jpg', '.jpeg', '.png'))]
        random.shuffle(images)  # Shuffle the images randomly

        # Calculate the number of images for the train-test split
        total_images = len(images)
        train_count = int(total_images * 0.8)  # 80% for training

        # Create class directories in train and test folders
        os.makedirs(os.path.join(train_directory, class_name), exist_ok=True)
        os.makedirs(os.path.join(test_directory, class_name), exist_ok=True)

        # Split and copy images to the respective directories
        for i, image in enumerate(images):
            src_path = os.path.join(class_dir, image)
            if i < train_count:
                dest_path = os.path.join(train_directory, class_name, image)
            else:
                dest_path = os.path.join(test_directory, class_name, image)

            shutil.copy(src_path, dest_path)

# Function to count the number of images in a directory
def count_images_in_directory(directory):
    count = 0
    for root, _, files in os.walk(directory):
        count += len([file for file in files if file.lower().endswith(('.jpg', '.jpeg', '.png'))])
    return count

# Print the number of images in each directory
print("\nNumber of images in each directory:")
print("Train Directory:", count_images_in_directory(train_directory))
print("Test Directory:", count_images_in_directory(test_directory))
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kausthubkannan/5-flower-types-classification-dataset?dataset_version_number=1...
# 100%|██████████| 242M/242M [00:04<00:00, 54.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1
#
# Number of images in each directory:
# Train Directory: 3999
# Test Directory: 1000

# %% [markdown]
# #### Load and Preprocess the Data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Assuming train_directory and test_directory are already defined
print('Train Directory:', train_directory)
print('Test Directory:', test_directory)

# Data augmentation and rescaling for the training set
# train_datagen = ImageDataGenerator(
#     rescale=1.0/255,  # Normalize pixel values to [0, 1]
#     rotation_range=30,  # Random rotations
#     width_shift_range=0.2,  # Random horizontal shifts
#     height_shift_range=0.2,  # Random vertical shifts
#     shear_range=0.2,  # Random shearing
#     zoom_range=0.2,  # Random zooming
#     horizontal_flip=True,  # Random horizontal flips
#     fill_mode='nearest'  # Filling strategy for augmented images
# )
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,        # Rotate images by up to 45 degrees
    width_shift_range=0.3,    # Shift horizontally by 30%
    height_shift_range=0.3,   # Shift vertically by 30%
    shear_range=0.3,          # Shear transformation
    zoom_range=0.4,           # Zoom in and out
    horizontal_flip=True,     # Flip horizontally
    fill_mode='nearest'
)

# Rescaling for the test set (no augmentation)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess images from the train directory
# train_generator = train_datagen.flow_from_directory(
#     train_directory,
#     target_size=(150, 150),  # Resize all images to 150x150
#     batch_size=32,
#     class_mode='categorical'  # Use 'binary' if you have two classes
# )
train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Load and preprocess images from the test directory
test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=(224, 224),  # Resize all images to 150x150
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Train Directory: /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1/train
# Test Directory: /root/.cache/kagglehub/datasets/kausthubkannan/5-flower-types-classification-dataset/versions/1/test
# Found 3999 images belonging to 5 classes.
# Found 1000 images belonging to 5 classes.

# %% [markdown]
# ###  v2.0 Define the CNN Model Architecture
#
#
#
# *   Adding batch normalization after each convolutional layer can stabilize and accelerate training.
# *   I will be consider adding more convolutional layers or filters to capture richer features.
# *   Experiment with increasing the number of neurons in the dense layer (e.g., 256 or 512) to capture more complex relationships.
# *   Consider using LeakyReLU or ELU as an alternative to ReLU to avoid issues like the "dying ReLU" problem.
# *   Add L2 regularization to further prevent overfitting

# %%
from tensorflow.keras import models, layers, Input
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.regularizers import l2

# Define the custom CNN model
def build_custom_cnn(input_shape=(224, 224, 3), num_classes=5):
    model = models.Sequential([
        # Input Layer
        Input(shape=input_shape),

        # Convolutional Layer 1
        layers.Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.01)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),


        # Convolutional Layer 2
        layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.01)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Convolutional Layer 3
        layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.01)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Convolutional Layer 4
        layers.Conv2D(256, (3, 3), activation='relu',kernel_regularizer=l2(0.01)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Fully Connected Layers
        layers.Flatten(),
        layers.Dense(1024, activation='relu', kernel_regularizer=l2(0.01)),
        layers.Dropout(0.5),  # Regularization
        layers.Dense(num_classes, activation='softmax')  # Output Layer
    ])

    return model

# Build the model
custom_model = build_custom_cnn()

# Compile the model
custom_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
)

# Print model summary
custom_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)                   │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 222, 222, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 109, 109, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 52, 52, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 24, 24, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 24, 24, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_17 (MaxPooling2D)      │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │      37,749,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │           5,125 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 38,145,221 (145.51 MB)
#  Trainable params: 38,144,261 (145.51 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# Preprocess the Data
# Use ImageDataGenerator for data preprocessing and augmentation. This ensures the model gets more diverse training examples.
#
#
# - Random transformations are applied to the training images to artificially increase dataset diversity and improve generalization.
#
# Normalization:
#
# Pixel values are scaled to the range [0, 1] for both training and testing datasets, improving training stability and convergence.
# Image Resizing:
#
# All images are resized to a uniform size of (150, 150) to match the input shape of the CNN.
#
# Data Shuffling:
#
# Training data is shuffled for better randomness during training.
# Testing data is not shuffled to ensure that predictions correspond to the same order as the true labels.
# Batch Size:
#
# A batch size of 32 is set for both datasets. This can be adjusted based on system memory and GPU capability.

# %% [markdown]
# ### Train the Model Train the CNN on the dataset:

# %%
## Train the model with 100 epochs

# from sklearn.utils.class_weight import compute_class_weight
# import numpy as np

# class_weights = compute_class_weight(
#     class_weight='balanced',
#     classes=np.unique(train_generator.classes),
#     y=train_generator.classes
# )

# class_weights_dict = dict(enumerate(class_weights))

# history = model.fit(
#     train_generator,
#     epochs=50,
#     class_weight=class_weights_dict
# )

# Train the model
history = custom_model.fit(
    train_generator,
    epochs=75,  # Adjust based on performance
    validation_data=test_generator
)
# Out:
# Epoch 1/75
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  13/125 ━━━━━━━━━━━━━━━━━━━━ 14:49 8s/step - accuracy: 0.2640 - loss: 51.1696 - precision: 0.2817 - recall: 0.2640

# %% [markdown]
# ### Evaluate on the Test Set,  after training, evaluate the model on the test set:

# %%
# Load the test data
test_datagen = ImageDataGenerator(rescale=1.0/255)
test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)

# Evaluate the model
test_loss, test_accuracy, test_precision, test_recall = custom_model.evaluate(test_generator)

# Print the results
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Precision: {test_precision * 100:.2f}%")
print(f"Test Recall: {test_recall * 100:.2f}%")
# Out:
# Found 1000 images belonging to 5 classes.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6529 - loss: 2.1859 - precision: 0.6997 - recall: 0.6188
# Test Loss: 2.1031
# Test Accuracy: 67.30%
# Test Precision: 72.55%
# Test Recall: 63.70%

# %% [markdown]
# ### Plot training and validation accuracy/loss:

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Evaluate the Model with Confusion Matrix

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Generate predictions
test_generator.reset()
predictions = custom_model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Confusion Matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# Classification Report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step
#               precision    recall  f1-score   support
#
#        Lilly       0.18      0.05      0.08       200
#        Lotus       0.21      0.24      0.23       200
#       Orchid       0.20      0.14      0.17       200
#    Sunflower       0.19      0.23      0.21       200
#        Tulip       0.17      0.29      0.22       200
#
#     accuracy                           0.19      1000
#    macro avg       0.19      0.19      0.18      1000
# weighted avg       0.19      0.19      0.18      1000

# %% [markdown]
# Visualizing Model Predictions

# %%
# Visualize predictions
def visualize_predictions(generator, num_images=10):
    class_labels = list(generator.class_indices.keys())
    batch = next(generator)
    images, labels = batch[0], batch[1]

    predictions = custom_model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(labels, axis=1)

    plt.figure(figsize=(15, 10))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i])
        plt.title(f"True: {class_labels[true_classes[i]]}\nPred: {class_labels[predicted_classes[i]]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Visualize predictions on the test set
visualize_predictions(test_generator, num_images=10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step

# %% [markdown]
# ### Area under the curve

# %% [markdown]
# Get the Predicted Probabilities

# %%
y_pred_prob = custom_model.predict(test_generator)  # Predicted probabilities for each class
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step

# %% [markdown]
# Binarize the True Labels

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
y_test_binarized = lb.fit_transform(test_generator.classes)  # True labels in binary format
class_names = test_generator.class_indices.keys()  # Class names

# %% [markdown]
# Calculate AUC and ROC for Each Class

# %%
from sklearn.metrics import roc_curve, auc

fpr = {}
tpr = {}
roc_auc = {}

for i, class_name in enumerate(class_names):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Print the AUC for each class
for i, class_name in enumerate(class_names):
    print(f"AUC for {class_name}: {roc_auc[i]:.2f}")
# Out:
# AUC for Lilly: 0.49
# AUC for Lotus: 0.46
# AUC for Orchid: 0.50
# AUC for Sunflower: 0.48
# AUC for Tulip: 0.51

# %% [markdown]
# Plot ROC Curves for All Classes

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
for i, class_name in enumerate(class_names):
    plt.plot(fpr[i], tpr[i], label=f'{class_name} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line (random classifier)
plt.title('ROC Curve for Multi-Class Classification')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
